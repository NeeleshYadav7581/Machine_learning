# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plot
import warnings
warnings.filterwarnings('ignore')

# %%
titanic = pd.read_csv('Titanic.csv')
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 228         1120         0       3
# 192         1084         0       3
# 361         1253         1       2
# 347         1239         1       3
# 287         1179         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 228                        Everett, Mr. Thomas James    male  40.5      0
# 192                van Billiard, Master. Walter John    male  11.5      1
# 361          Mallet, Mrs. Albert (Antoinette Magnin)  female  24.0      1
# 347  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0      0
# 287                       Snyder, Mr. John Pillsbury    male  24.0      1
#
#      Parch           Ticket     Fare Cabin Embarked
# 228      0        C.A. 6212  15.1000   NaN        S
# 192      1         A/5. 851  14.5000   NaN        S
# 361      1  S.C./PARIS 2079  37.0042   NaN        C
# 347      0             2688   7.2292   NaN        C
# 287      0            21228  82.2667   B45        S

# %%
tips = pd.read_csv('tips.csv')
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 122       14.26  2.50    Male     No  Thur   Lunch     2              7.13
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2              7.84
# 160       21.50  3.50    Male     No   Sun  Dinner     4              5.38
# 133       12.26  2.00  Female     No  Thur   Lunch     2              6.13
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2             14.22
#
#            Payer Name         CC Number Payment ID
# 122      Perry Garcia   180034646320219   Thur3579
# 190      Riley Barnes   180053549128800    Sun5104
# 160   Travis Gonzalez  3527668419764685     Sun245
# 133      Kaitlin Wolf      676348318145   Thur1561
# 192  Dr. Jeffrey Rich     4737538358295   Thur4334

# %%
flights = pd.read_csv('flights.csv')
flights.sample(5)
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 22993    22993  2013      1   27    1545.0            1550       -5.0
# 232799  232799  2013      6   12    1234.0            1237       -3.0
# 81969    81969  2013     11   29    1442.0            1443       -1.0
# 192252  192252  2013      4   29    1835.0            1837       -2.0
# 329330  329330  2013      9   23     639.0             640       -1.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 22993     1743.0            1710       33.0  ...   4215   N960WN    EWR  MDW
# 232799    1552.0            1544        8.0  ...   1700   N24729    EWR  SFO
# 81969     1650.0            1703      -13.0  ...   4181   N16963    EWR  MCI
# 192252    2049.0            2132      -43.0  ...    711   N527JB    JFK  LAS
# 329330     908.0             854       14.0  ...     27   N3773D    JFK  ATL
#
#        air_time  distance  hour  minute            time_hour  \
# 22993     159.0       711    15      50  2013-01-27 15:00:00
# 232799    358.0      2565    12      37  2013-06-12 12:00:00
# 81969     170.0      1092    14      43  2013-11-29 14:00:00
# 192252    284.0      2248    18      37  2013-04-29 18:00:00
# 329330    114.0       760     6      40  2013-09-23 06:00:00
#
#                             name
# 22993     Southwest Airlines Co.
# 232799     United Air Lines Inc.
# 81969   ExpressJet Airlines Inc.
# 192252           JetBlue Airways
# 329330      Delta Air Lines Inc.
#
# [5 rows x 21 columns]

# %%
iris = pd.read_csv('IRIS.csv')
iris.sample(5)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 77           6.7          3.0           5.0          1.7  Iris-versicolor
# 86           6.7          3.1           4.7          1.5  Iris-versicolor
# 81           5.5          2.4           3.7          1.0  Iris-versicolor
# 17           5.1          3.5           1.4          0.3      Iris-setosa
# 35           5.0          3.2           1.2          0.2      Iris-setosa

# %% [markdown]
# Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex', style='smoker' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Bar Plot (Numerical - Categorical)

# %%
sns.barplot(data=titanic , x='Pclass' , y= 'Age', hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# Box Plot (Numerical - Categorical)
